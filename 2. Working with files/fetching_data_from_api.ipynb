# %% [markdown]
# # working with APIs

# %% [markdown]
# ##### when we hit APi we usually get data in the form of json

# %%
import pandas as pd
import requests

# %%
# in url we will give API url
# we will give response to pandas dataframe to get it 
url = ""
response = requests.get(url)
pd.DataFrame(response.json())

# %%
# we can convert api data to csv by pd.to_csv() so that we dont hit API again and again
