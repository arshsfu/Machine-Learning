# %% [markdown]
# # EDA using bivariate/ multivariate Analysis

# %% [markdown]
# <p>
#     When we perform EDA on two or more than two variables that is bivariate Analysis
#
#
# </p>

# %%
import pandas as pd
import seaborn as sns

# %%
# For numerical numerical columns we understand the columns using scatterplot
tips = sns.load_dataset('')
tips.head()
sns.scatterplot(tips['total_bill'], tips['tip'], hue= tips['sex'], style=tips['smokers'])
# total_bill and tip are 2 columns here we will get the plot where we can see the relationship btw both as how one changes as other changes
# hue is the parameter which tells me i the plot who are male and who are female
# if i want i can also see out of this data who is smoker and who is not by giving style=tips['smokers']
# parameter size=tips['size'] shows the size of points on graph represents the quantity of column named size

# %%
sns.barplot(df['Pclass'], df['Age'], hue=[df['Sex']])
# lets say i want to know the average age of people travelling in titanic dataset travelliing in different Pclass
# hue works same here too if i want to see sex of people travelling in different Pclass

# %%
# For numerical-categorical combination columns
# x axis in boxplot is given categorical and y axis = numerical
sns.boxplot(df['Sex'], df['Age'], hue=df['Survived'])

# %%
# FOr Distplot (Numerical-categorical)
sns.distplot(titanic['Age'])

# %%
# For categorical - categorical columns
pd.crosstab(titanic['Pclass'], titanic['Survived'])
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))

# %%
# For categorical - categorical columns
pd.crosstab(titanic['Sibsp'], titanic['Survived'])
sns.clustermap(pd.crosstab(titanic['Pclass'], titanic['Survived']))

# %%
# pairplot gives us all the scatterplots btw all the numerical columns in the dataset 
sns.pairplot(iris, hue='species')

# %%
# Lineplot is a special case of scatter plot 
# used in numerical - numerical 
# mainly used when quantity on x axis is time based
sns.lineplot()
