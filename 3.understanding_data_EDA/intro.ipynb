# %% [markdown]
# # understanding our data

# %% [markdown]
# <P>
#     We ususally ask some questions to learn about some data i.e given below
# </P>

# %%
import pandas as pd

# %% [markdown]
# # 1. How big is the data ?

# %%
df = pd.read_csv('tested.csv')
df.shape
# Out:
# (418, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
#give me 1st some rows
df.head()
#give me 5 random rows
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 334         1226         0       3                Cor, Mr. Ivan    male  27.0
# 216         1108         1       3   Mahon, Miss. Bridget Delia  female   NaN
# 355         1247         0       1     Julian, Mr. Henry Forbes    male  50.0
# 89           981         0       2  Wells, Master. Ralph Lester    male   2.0
# 176         1068         1       2         Sincock, Miss. Maude  female  20.0
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked
# 334      0      0      349229   7.8958   NaN        S
# 216      0      0      330924   7.8792   NaN        Q
# 355      0      0      113044  26.0000   E60        S
# 89       1      1       29103  23.0000   NaN        S
# 176      0      0  C.A. 33112  36.7500   NaN        S

# %% [markdown]
# # 3. What is the data type of our data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # 4. Are there any missing values ?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically ?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool>

# %% [markdown]
# # 7. Is there any correlation btw columns ?

# %%
# ususally this is the function but we need to drop string columns as correlation is calculated btw mathematically values

df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 # ususally this is the function but we need to drop string columns
#       2
# ----> 3 df.corr()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11052         """  # noqa: E501
#   11053         data = self._get_numeric_data() if numeric_only else self
#   11054         cols = data.columns
#   11055         idx = cols.copy()
# > 11056         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11057
#   11058         if method == "pearson":
#   11059             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...
